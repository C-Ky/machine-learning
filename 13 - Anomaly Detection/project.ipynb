# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./data/dataset.csv")

# %%
plt.figure()
plt.plot(df['p1'][df['day_cycle_window']=='1_1_1'])
plt.plot(df['p1'][df['day_cycle_window']=='1_1_2'])
plt.plot(df['p1'][df['day_cycle_window']=='1_1_3'])

# %%
plt.figure()
plt.plot(df['p1'][df['day_cycle_window']=='1_1_1'])
plt.plot(df['p1'][df['day_cycle_window']=='1_2_1'])
plt.plot(df['p1'][df['day_cycle_window']=='1_3_1'])

# %%
plt.figure()
plt.plot(df['p1'][df['day_cycle_window']=='1_1_1'])
plt.plot(df['p1'][df['day_cycle_window']=='1_2_1'])
plt.plot(df['p1'][df['day_cycle_window']=='1_3_1'])

# %%
plt.figure()
plt.plot(df['p1'][df['day_cycle_window']=='1_1_1'])
plt.plot(df['p1'][df['day_cycle_window']=='2_1_1'])
plt.plot(df['p1'][df['day_cycle_window']=='3_1_1'])

# %%
def 1_1():
    t = df['day_cycle_window'].values
    for i in t:
        return i.split('_')[0] == '1' and i.split('_')[1] == '1'
# Out:
# array(['1_1_1', '1_1_1', '1_1_1', ..., '4_4_160', '4_4_160', '4_4_160'],
#       dtype=object)

# %%
df['day_cycle_window'][:][2]
# Out:
# '1_1_1'

# %% [markdown]
# 1 mesure toutes les secondes\
# tous les cycles commencent et terminent dans les mêmes conditions mais la durée totale du cycle peut varier
